# %%
import pandas as pd

# %%
df = pd.read_csv('./phones_New.csv')
df
# Out:
#                  product_name  \
# 0                  OnePlus 6T
# 1     Samsung Galaxy S20 Plus
# 2             Apple iPhone XR
# 3             Apple iPhone 11
# 4     Apple iPhone 11 Pro Max
# 5               OnePlus 8 Pro
# 6           Google Pixel 4 XL
# 7               OnePLus 7 Pro
# 8           Apple Macbook Air
# 9   Apple Macbook Pro (512GB)
# 10  Apple Macbook Pro (512GB)
# 11  Dell Inspiron Touchscreen
# 12  Acer Aspire 5 Slim Laptop
# 13         Lenovo 130S 11IGM
# 14              ASUS VivoBook
# 15              Acer Aspire 5
# 16          2020 HP 15 Laptop
# 17        2020 Lenovo Ideapad
#
#                                           product_url  \
# 0   https://www.amazon.in/OnePlus-Mirror-Black-128...
# 1   https://www.amazon.com/Samsung-Unlocked-Finger...
# 2   https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 3   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 4   https://www.amazon.com/Apple-iPhone-Midnight-U...
# ...

# %%
ram = 8
battery = 4000
budget = 3500
camera = 20

df.product_name
# Out:
# 0                    OnePlus 6T
# 1       Samsung Galaxy S20 Plus
# 2               Apple iPhone XR
# 3               Apple iPhone 11
# 4       Apple iPhone 11 Pro Max
# 5                 OnePlus 8 Pro
# 6             Google Pixel 4 XL
# 7                 OnePLus 7 Pro
# 8             Apple Macbook Air
# 9     Apple Macbook Pro (512GB)
# 10    Apple Macbook Pro (512GB)
# 11    Dell Inspiron Touchscreen
# 12    Acer Aspire 5 Slim Laptop
# 13           Lenovo 130S 11IGM
# 14                ASUS VivoBook
# 15                Acer Aspire 5
# 16            2020 HP 15 Laptop
# 17          2020 Lenovo Ideapad
# Name: product_name, dtype: object
